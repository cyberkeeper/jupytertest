# %% [markdown]
# # Welcome![pythonlogo.jpg](attachment:6d33c425-34b3-4e80-b68d-713bd7ee0b1e.jpg)
# <b>Traditionally the first program written in a new language writes "Hello world" to the screen.
#
# We do this using the print command which looks like,
# print("something")
#
# Python is very accepting and will also accept single quotes,
# print('something')
#
# Use the print comamnd to display "Hello world" on screen
# Once you have entered the command click the play button at the top of the screen or hold down shift and press enter

# %%
print('hello world')
# Out:
# hello world

# %% [markdown]
# There are several ways to print <b>multiple</b> line of code,
# <ol>
# <li>type the comment multiple times</li>
# <li>or use a loop</li>
# </ol>
#
# The first way might be ok for printing things out twice but would be tedious for more items. Python gives us a few ways to do this. First one we will look at is the <b>for</b> loop
#
# A for loop looks like  this

# %% [raw]
# val = 1
# for counter in range (0,5):
#     val += 1
#     print(val)

# %% [markdown]
# Try this code in the space below,

# %%
val=1
for counter in range (0,5):
    val +=1
    print(val)
# Out:
# 2
# 3
# 4
# 5
# 6
